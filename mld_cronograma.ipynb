# %% [markdown]
# ## Machine Learning Descomplicado
# Rafinha dos dados
#
# início em 09/08/2021<BR>
# by geanclm

# %% [markdown]
# suporte<br>
# alunos@rafinhadosdados.com.br
#
# comunidade do facebbok<br>
# dúvidas teóricas<br>
#
# Sparkle

# %% [markdown]
# ### Cronograma de Liberação dos Módulos
# by geanclm

# %%
import pandas as pd
from pathlib import Path

# %%
FilePath = Path(r'cronograma.csv')
df = pd.read_csv(FilePath, sep=';')

# %%
# renomear campos para um nome mais prático no script python
df = df.rename(columns={'DATA DE LIBERAÇÃO': 'data'})
df = df.rename(columns={'Módulo': 'module'})

# %%
# # substituindo caracteres da data
# df['data'] = df['data'].apply(lambda x: str(x).replace("/" , "-"))

df.loc[:,'data'] = pd.to_datetime(df.data, format='%d/%m/%Y')

# %%
df
# Out:
#                                       module       data
# 0                                 Introdução 2021-08-09
# 1               Programação Python e Jupyter 2021-08-09
# 2   Princípios de Machine Learning (parte 1) 2021-08-09
# 3   Princípios de Machine Learning (parte 2) 2021-08-16
# 4                    Classificação (parte 1) 2021-08-23
# 5                    Classificação (parte 2) 2021-08-30
# 6                    Classificação (parte 3) 2021-09-06
# 7                 Classificação (Exercícios) 2021-09-13
# 8                    Classificação (parte 4) 2021-09-20
# 9                    Classificação (parte 5) 2021-09-27
# 10                       Regressão (parte 1) 2021-10-04
# 11                       Regressão (parte 2) 2021-10-11
# 12                       Regressão (parte 3) 2021-10-18
# 13                   Redes Neurais (parte 1) 2021-10-25
# 14                   Redes Neurais (parte 2) 2021-11-01
# 15                     Agrupamento (parte 1) 2021-11-08
# 16                     Agrupamento (parte 2) 2021-11-15
# 17                     Agrupamento (parte 3) 2021-11-22
# 18                     Agrupamento (parte 4) 2021-11-29
# 19                     Agrupamento (parte 5) 2021-12-06
# 20        Dataprep e "juntar tudo" (parte 1) 2021-12-13
# 21        Dataprep e "juntar tudo" (parte 2) 2021-12-20
# 22        Dataprep e "juntar tudo" (parte 3) 2021-12-27
# 23        Dataprep e "juntar tudo" (parte 4) 2022-01-03
# 24        Dataprep e "juntar tudo" (parte 5) 2022-01-10

# %%
# retorna uma busca pela data escolhida
df.loc[df.data=='2021-08-16']
# Out:
#                                      module       data
# 3  Princípios de Machine Learning (parte 2) 2021-08-16
